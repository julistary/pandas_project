# %% [markdown]
# # 1. Preliminary Cleaning

# %% [markdown]
# <img width=300 src=https://media.giphy.com/media/Egt3zwbUgBo08/giphy.gif>

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### Importing DataFrame

# %%
df = pd.read_csv("attacks.csv",encoding = "ISO-8859-1")

# %%
df
# Out:
#                        Date  Year        Type    Country  \
# Case_Number
# 2018.06.25      25-Jun-2018  2018     Boating        USA
# 2018.06.18      18-Jun-2018  2018  Unprovoked        USA
# 2018.06.09      09-Jun-2018  2018     Invalid        USA
# 2018.06.08      08-Jun-2018  2018  Unprovoked  AUSTRALIA
# 2018.06.04      04-Jun-2018  2018    Provoked     MEXICO
# ...                     ...   ...         ...        ...
# 1554.00.00         Ca. 1554  1554  Unprovoked     FRANCE
# 1543.00.00         Ca. 1543  1543  Unprovoked  VENEZUELA
# 0500.00.00   Circa 500 A.D.   500  Unprovoked     MEXICO
# 0077.00.00         77  A.D.    77  Unprovoked        NaN
# 0005.00.00       Ca. 5 A.D.     5  Unprovoked  AUSTRALIA
#
#                                     Area                        Location  \
# Case_Number
# 2018.06.25                    California     Oceanside, San Diego County
# 2018.06.18                       Georgia  St. Simon Island, Glynn County
# 2018.06.09                        Hawaii                    Habush, Oahu
# 2018.06.08               New South Wales              Arrawarra Headland
# 2018.06.04                        Colima                        La Ticla
# ...                                  ...                             ...
# 1554.00.00             Nice & Marseilles                             NaN
# 1543.00.00   Magarita or Cubagua Islands                             NaN
# 0500.00.00                           NaN                             NaN
# 0077.00.00                    Ionian Sea                             NaN
# 0005.00.00               New South Wales                           Bondi
#
#                   Activity                   Name Sex  Age  \
# Case_Number
# 2018.06.25        Paddling            Julie Wolfe   F   57
# 2018.06.18        Standing        Adyson McNeely    F   11
# 2018.06.09         Surfing            John Denges   M   48
# 2018.06.08         Surfing                   male   M  NaN
# 2018.06.04     Free diving         Gustavo Ramos    M  NaN
# ...                    ...                    ...  ..  ...
# 1554.00.00             NaN  males (wearing armor)   M  NaN
# 1543.00.00    Pearl diving           Indian slave   M  NaN
# 0500.00.00             NaN                   male   M  NaN
# 0077.00.00   Sponge diving                  males   M  NaN
# 0005.00.00             NaN                   male   M  NaN
#
#                                                         Injury    Fatal  \
# Case_Number
# 2018.06.25   No injury to occupant, outrigger canoe and pad...        N
# 2018.06.18                          Minor injury to left thigh        N
# 2018.06.09        Injury to left lower leg from surfboard skeg        N
# 2018.06.08                           Minor injury to lower leg        N
# 2018.06.04   Lacerations to leg & hand shark PROVOKED INCIDENT        N
# ...                                                        ...      ...
# 1554.00.00                                                 NaN  UNKNOWN
# 1543.00.00                                               FATAL        Y
# 0500.00.00                                        Foot severed        N
# 0077.00.00                                               FATAL        Y
# 0005.00.00   Aboriginal rock carving depicts man being atta...        N
#
#                       Time                Species  \
# Case_Number
# 2018.06.25           18h00            White shark
# 2018.06.18   14h00  -15h00                    NaN
# 2018.06.09           07h45                    NaN
# 2018.06.08             NaN              2 m shark
# 2018.06.04             NaN        Tiger shark, 3m
# ...                    ...                    ...
# 1554.00.00             NaN  Possibly white sharks
# 1543.00.00             NaN                    NaN
# 0500.00.00             NaN                    NaN
# 0077.00.00             NaN                    NaN
# 0005.00.00             NaN                    NaN
#
#                                         Investigator or Source
# Case_Number
# 2018.06.25                                    R. Collier, GSAF
# 2018.06.18                      K.McMurray, TrackingSharks.com
# 2018.06.09                      K.McMurray, TrackingSharks.com
# 2018.06.08                                      B. Myatt, GSAF
# 2018.06.04                                           A .Kipper
# ...                                                        ...
# 1554.00.00                                        G. Rondelet
# 1543.00.00                                           J. Castro
# 0500.00.00                                           J. Castro
# 0077.00.00   Perils mentioned by Pliny the Elder (23 A.D. t...
# 0005.00.00                                     Waverly Library
#
# [6175 rows x 15 columns]

# %%
df.shape
# Out:
# (25723, 24)

# %% [markdown]
# ### Dropping duplicates

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Renaming columns

# %%
df.rename(columns = {"Case Number" : "Case_Number", "Species " : "Species", "Sex " : "Sex", "Fatal (Y/N)" : "Fatal"}, inplace=True)

# %% [markdown]
# ### Deleting rows without relevant data

# %%
df.dropna(axis = 0, how="all",subset=['Date', 'Year', 'Type', 'Country', 'Area', 'Location',
       'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal', 'Time', 'Species',
       'Investigator or Source'],inplace=True)

# %%
df.columns
# Out:
# Index(['Case_Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal', 'Time', 'Species',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# ### Deleting rows without relevant data

# %%
df.drop(['Case Number.1', 'Case Number.2', 'Unnamed: 22', 'Unnamed: 23','pdf','href formula','href','original order'], axis=1, inplace = True)

# %% [markdown]
# ### Changing Index

# %%
df.set_index("Case_Number",inplace=True)

# %% [markdown]
# ### Changing Column Year

# %%
df = df[df["Year"].notna()]
df["Year"] = df["Year"].astype(int)

# %%
df = df[df.Year != 0]

# %% [markdown]
# ### Exporting

# %%
df.to_csv("./attack_clean.csv")

# %%
df
# Out:
#                        Date  Year        Type    Country  \
# Case_Number
# 2018.06.25      25-Jun-2018  2018     Boating        USA
# 2018.06.18      18-Jun-2018  2018  Unprovoked        USA
# 2018.06.09      09-Jun-2018  2018     Invalid        USA
# 2018.06.08      08-Jun-2018  2018  Unprovoked  AUSTRALIA
# 2018.06.04      04-Jun-2018  2018    Provoked     MEXICO
# ...                     ...   ...         ...        ...
# 1554.00.00         Ca. 1554  1554  Unprovoked     FRANCE
# 1543.00.00         Ca. 1543  1543  Unprovoked  VENEZUELA
# 0500.00.00   Circa 500 A.D.   500  Unprovoked     MEXICO
# 0077.00.00         77  A.D.    77  Unprovoked        NaN
# 0005.00.00       Ca. 5 A.D.     5  Unprovoked  AUSTRALIA
#
#                                     Area                        Location  \
# Case_Number
# 2018.06.25                    California     Oceanside, San Diego County
# 2018.06.18                       Georgia  St. Simon Island, Glynn County
# 2018.06.09                        Hawaii                    Habush, Oahu
# 2018.06.08               New South Wales              Arrawarra Headland
# 2018.06.04                        Colima                        La Ticla
# ...                                  ...                             ...
# 1554.00.00             Nice & Marseilles                             NaN
# 1543.00.00   Magarita or Cubagua Islands                             NaN
# 0500.00.00                           NaN                             NaN
# 0077.00.00                    Ionian Sea                             NaN
# 0005.00.00               New South Wales                           Bondi
#
#                   Activity                   Name Sex  Age  \
# Case_Number
# 2018.06.25        Paddling            Julie Wolfe   F   57
# 2018.06.18        Standing        Adyson McNeely    F   11
# 2018.06.09         Surfing            John Denges   M   48
# 2018.06.08         Surfing                   male   M  NaN
# 2018.06.04     Free diving         Gustavo Ramos    M  NaN
# ...                    ...                    ...  ..  ...
# 1554.00.00             NaN  males (wearing armor)   M  NaN
# 1543.00.00    Pearl diving           Indian slave   M  NaN
# 0500.00.00             NaN                   male   M  NaN
# 0077.00.00   Sponge diving                  males   M  NaN
# 0005.00.00             NaN                   male   M  NaN
#
#                                                         Injury    Fatal  \
# Case_Number
# 2018.06.25   No injury to occupant, outrigger canoe and pad...        N
# 2018.06.18                          Minor injury to left thigh        N
# 2018.06.09        Injury to left lower leg from surfboard skeg        N
# 2018.06.08                           Minor injury to lower leg        N
# 2018.06.04   Lacerations to leg & hand shark PROVOKED INCIDENT        N
# ...                                                        ...      ...
# 1554.00.00                                                 NaN  UNKNOWN
# 1543.00.00                                               FATAL        Y
# 0500.00.00                                        Foot severed        N
# 0077.00.00                                               FATAL        Y
# 0005.00.00   Aboriginal rock carving depicts man being atta...        N
#
#                       Time                Species  \
# Case_Number
# 2018.06.25           18h00            White shark
# 2018.06.18   14h00  -15h00                    NaN
# 2018.06.09           07h45                    NaN
# 2018.06.08             NaN              2 m shark
# 2018.06.04             NaN        Tiger shark, 3m
# ...                    ...                    ...
# 1554.00.00             NaN  Possibly white sharks
# 1543.00.00             NaN                    NaN
# 0500.00.00             NaN                    NaN
# 0077.00.00             NaN                    NaN
# 0005.00.00             NaN                    NaN
#
#                                         Investigator or Source
# Case_Number
# 2018.06.25                                    R. Collier, GSAF
# 2018.06.18                      K.McMurray, TrackingSharks.com
# 2018.06.09                      K.McMurray, TrackingSharks.com
# 2018.06.08                                      B. Myatt, GSAF
# 2018.06.04                                           A .Kipper
# ...                                                        ...
# 1554.00.00                                        G. Rondelet
# 1543.00.00                                           J. Castro
# 0500.00.00                                           J. Castro
# 0077.00.00   Perils mentioned by Pliny the Elder (23 A.D. t...
# 0005.00.00                                     Waverly Library
#
# [6175 rows x 15 columns]
